# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/m5/s7c6nvgs0q321pw3z5mmqc1r0000gn/T/pip-req-build-28bi974h
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/m5/s7c6nvgs0q321pw3z5mmqc1r0000gn/T/pip-req-build-28bi974h
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (2.34.2)
# Requirement already satisfied: numpy in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (2.4.6)
# Requirement already satisfied: matplotlib in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (3.10.9)
# Requirement already satisfied: scipy in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (2026.5.20)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o),
);


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_normal_(layer_in.weight)
        layer_in.bias.data.fill_(0.0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=1000, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=1000, out_features=1000, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=1000, out_features=1000, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=1000, out_features=1000, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=1000, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.563343, train error 62.97,  test loss 1.640649, test error 66.10
# Epoch     1, train loss 1.273501, train error 48.50,  test loss 1.489625, test error 58.15
# Epoch     2, train loss 0.903080, train error 29.82,  test loss 1.229816, test error 46.97
# Epoch     3, train loss 0.734267, train error 27.47,  test loss 1.194690, test error 44.58
# Epoch     4, train loss 0.522807, train error 18.53,  test loss 1.049806, test error 38.47
# Epoch     5, train loss 0.305169, train error 10.20,  test loss 1.070708, test error 34.90
# Epoch     6, train loss 0.271120, train error 8.95,  test loss 1.177935, test error 37.80
# Epoch     7, train loss 0.264695, train error 8.75,  test loss 1.298471, test error 35.93
# Epoch     8, train loss 0.117417, train error 3.57,  test loss 1.159797, test error 33.72
# Epoch     9, train loss 0.116026, train error 3.47,  test loss 1.339189, test error 34.12
# Epoch    10, train loss 0.014222, train error 0.07,  test loss 1.084335, test error 29.60
# Epoch    11, train loss 0.005581, train error 0.00,  test loss 1.101827, test error 28.43
# Epoch    12, train loss 0.003375, train error 0.00,  test loss 1.120895, test error 28.25
# Epoch    13, train loss 0.002592, train error 0.00,  test loss 1.145717, test error 28.43
# Epoch    14, train loss 0.002130, train error 0.00,  test loss 1.165049, test error 28.38
# Epoch    15, train loss 0.001812, train error 0.00,  test loss 1.182585, test error 28.07
# Epoch    16, train loss 0.001582, train error 0.00,  test loss 1.198251, test error 28.10
# Epoch    17, train loss 0.001406, train error 0.00,  test loss 1.210774, test error 28.00
# Epoch    18, train loss 0.001263, train error 0.00,  test loss 1.224862, test error 28.07
# Epoch    19, train loss 0.001147, train error 0.00,  test loss 1.235273, test error 28.03
# Epoch    20, train loss 0.001097, train error 0.00,  test loss 1.240247, test error 28.12
# Epoch    21, train loss 0.001052, train error 0.00,  test loss 1.245668, test error 28.18
# Epoch    22, train loss 0.001010, train error 0.00,  test loss 1.250662, test error 28.12
# Epoch    23, train loss 0.000972, train error 0.00,  test loss 1.255101, test error 28.10
# Epoch    24, train loss 0.000936, train error 0.00,  test loss 1.260018, test error 28.10
# Epoch    25, train loss 0.000902, train error 0.00,  test loss 1.264078, test error 28.18
# Epoch    26, train loss 0.000871, train error 0.00,  test loss 1.268697, test error 28.10
# Epoch    27, train loss 0.000842, train error 0.00,  test loss 1.273108, test error 28.18
# Epoch    28, train loss 0.000815, train error 0.00,  test loss 1.276962, test error 28.18
# Epoch    29, train loss 0.000789, train error 0.00,  test loss 1.280835, test error 28.10
# Epoch    30, train loss 0.000777, train error 0.00,  test loss 1.282917, test error 28.10
# Epoch    31, train loss 0.000765, train error 0.00,  test loss 1.284861, test error 28.03
# Epoch    32, train loss 0.000754, train error 0.00,  test loss 1.286721, test error 28.05
# Epoch    33, train loss 0.000742, train error 0.00,  test loss 1.288588, test error 28.03
# Epoch    34, train loss 0.000732, train error 0.00,  test loss 1.290424, test error 28.05
# Epoch    35, train loss 0.000721, train error 0.00,  test loss 1.292262, test error 28.03
# Epoch    36, train loss 0.000711, train error 0.00,  test loss 1.293988, test error 28.00
# Epoch    37, train loss 0.000701, train error 0.00,  test loss 1.295832, test error 28.05
# Epoch    38, train loss 0.000692, train error 0.00,  test loss 1.297550, test error 28.00
# Epoch    39, train loss 0.000682, train error 0.00,  test loss 1.299357, test error 28.00
# Epoch    40, train loss 0.000677, train error 0.00,  test loss 1.300198, test error 28.03
# Epoch    41, train loss 0.000673, train error 0.00,  test loss 1.301062, test error 28.03
# Epoch    42, train loss 0.000668, train error 0.00,  test loss 1.301919, test error 28.00
# Epoch    43, train loss 0.000664, train error 0.00,  test loss 1.302811, test error 28.03
# Epoch    44, train loss 0.000660, train error 0.00,  test loss 1.303580, test error 28.00
# Epoch    45, train loss 0.000655, train error 0.00,  test loss 1.304420, test error 28.03
# Epoch    46, train loss 0.000651, train error 0.00,  test loss 1.305306, test error 28.00
# Epoch    47, train loss 0.000647, train error 0.00,  test loss 1.306109, test error 28.03
# Epoch    48, train loss 0.000643, train error 0.00,  test loss 1.306889, test error 28.00
# Epoch    49, train loss 0.000639, train error 0.00,  test loss 1.307724, test error 28.07
# Epoch    50, train loss 0.000637, train error 0.00,  test loss 1.308084, test error 28.00
# Epoch    51, train loss 0.000635, train error 0.00,  test loss 1.308549, test error 28.07
# Epoch    52, train loss 0.000633, train error 0.00,  test loss 1.308921, test error 28.07
# Epoch    53, train loss 0.000631, train error 0.00,  test loss 1.309354, test error 28.05
# Epoch    54, train loss 0.000629, train error 0.00,  test loss 1.309724, test error 28.05
# Epoch    55, train loss 0.000627, train error 0.00,  test loss 1.310180, test error 28.07
# Epoch    56, train loss 0.000625, train error 0.00,  test loss 1.310518, test error 28.07
# Epoch    57, train loss 0.000623, train error 0.00,  test loss 1.310960, test error 28.05
# Epoch    58, train loss 0.000621, train error 0.00,  test loss 1.311300, test error 28.07
# Epoch    59, train loss 0.000619, train error 0.00,  test loss 1.311729, test error 28.05
# Epoch    60, train loss 0.000618, train error 0.00,  test loss 1.311920, test error 28.07
# Epoch    61, train loss 0.000617, train error 0.00,  test loss 1.312137, test error 28.05
# Epoch    62, train loss 0.000616, train error 0.00,  test loss 1.312324, test error 28.05
# Epoch    63, train loss 0.000615, train error 0.00,  test loss 1.312515, test error 28.05
# Epoch    64, train loss 0.000614, train error 0.00,  test loss 1.312709, test error 28.03
# Epoch    65, train loss 0.000613, train error 0.00,  test loss 1.312908, test error 28.03
# Epoch    66, train loss 0.000612, train error 0.00,  test loss 1.313101, test error 28.03
# Epoch    67, train loss 0.000611, train error 0.00,  test loss 1.313308, test error 28.03
# Epoch    68, train loss 0.000610, train error 0.00,  test loss 1.313494, test error 28.03
# Epoch    69, train loss 0.000609, train error 0.00,  test loss 1.313680, test error 28.05
# Epoch    70, train loss 0.000609, train error 0.00,  test loss 1.313777, test error 28.05
# Epoch    71, train loss 0.000609, train error 0.00,  test loss 1.313879, test error 28.05
# Epoch    72, train loss 0.000608, train error 0.00,  test loss 1.313969, test error 28.03
# Epoch    73, train loss 0.000608, train error 0.00,  test loss 1.314069, test error 28.05
# Epoch    74, train loss 0.000607, train error 0.00,  test loss 1.314166, test error 28.05
# Epoch    75, train loss 0.000607, train error 0.00,  test loss 1.314265, test error 28.05
# Epoch    76, train loss 0.000606, train error 0.00,  test loss 1.314365, test error 28.05
# Epoch    77, train loss 0.000606, train error 0.00,  test loss 1.314455, test error 28.07
# Epoch    78, train loss 0.000605, train error 0.00,  test loss 1.314552, test error 28.07
# Epoch    79, train loss 0.000605, train error 0.00,  test loss 1.314653, test error 28.07
# Epoch    80, train loss 0.000605, train error 0.00,  test loss 1.314697, test error 28.07
# Epoch    81, train loss 0.000604, train error 0.00,  test loss 1.314746, test error 28.07
# Epoch    82, train loss 0.000604, train error 0.00,  test loss 1.314791, test error 28.07
# Epoch    83, train loss 0.000604, train error 0.00,  test loss 1.314843, test error 28.07
# Epoch    84, train loss 0.000604, train error 0.00,  test loss 1.314893, test error 28.07
# Epoch    85, train loss 0.000604, train error 0.00,  test loss 1.314937, test error 28.07
# Epoch    86, train loss 0.000603, train error 0.00,  test loss 1.314983, test error 28.07
# Epoch    87, train loss 0.000603, train error 0.00,  test loss 1.315032, test error 28.07
# Epoch    88, train loss 0.000603, train error 0.00,  test loss 1.315079, test error 28.07
# Epoch    89, train loss 0.000603, train error 0.00,  test loss 1.315127, test error 28.07
# Epoch    90, train loss 0.000603, train error 0.00,  test loss 1.315150, test error 28.07
# Epoch    91, train loss 0.000602, train error 0.00,  test loss 1.315171, test error 28.07
# Epoch    92, train loss 0.000602, train error 0.00,  test loss 1.315196, test error 28.07
# Epoch    93, train loss 0.000602, train error 0.00,  test loss 1.315216, test error 28.07
# Epoch    94, train loss 0.000602, train error 0.00,  test loss 1.315238, test error 28.07
# Epoch    95, train loss 0.000602, train error 0.00,  test loss 1.315261, test error 28.07
# Epoch    96, train loss 0.000602, train error 0.00,  test loss 1.315285, test error 28.07
# Epoch    97, train loss 0.000602, train error 0.00,  test loss 1.315306, test error 28.07
# Epoch    98, train loss 0.000602, train error 0.00,  test loss 1.315328, test error 28.07
# Epoch    99, train loss 0.000602, train error 0.00,  test loss 1.315350, test error 28.07

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
