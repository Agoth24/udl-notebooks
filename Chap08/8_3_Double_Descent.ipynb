# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('mps' if torch.mps.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: mps

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.8
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 6400
# Examples in test set: 1600
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for _, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 == 0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return n_params

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302822, train error 89.78,  test loss 2.303653, test error 90.25
# Epoch   100, train loss 2.302482, train error 89.75,  test loss 2.302617, test error 90.25
# Epoch   200, train loss 2.302478, train error 89.75,  test loss 2.302594, test error 90.25
# Epoch   300, train loss 2.302485, train error 89.75,  test loss 2.302688, test error 90.25
# Epoch   400, train loss 2.302491, train error 89.75,  test loss 2.302566, test error 90.25
# Epoch   500, train loss 2.302485, train error 89.75,  test loss 2.302560, test error 90.25
# Epoch   600, train loss 2.302477, train error 89.81,  test loss 2.302575, test error 89.31
# Epoch   700, train loss 2.302479, train error 89.75,  test loss 2.302566, test error 90.25
# Epoch   800, train loss 2.302477, train error 89.81,  test loss 2.302599, test error 89.31
# Epoch   900, train loss 2.302480, train error 89.75,  test loss 2.302623, test error 90.25
# Training model with   4 hidden variables
# Epoch     0, train loss 2.223875, train error 84.97,  test loss 2.196264, test error 84.38
# Epoch   100, train loss 1.783669, train error 65.36,  test loss 1.608728, test error 62.56
# Epoch   200, train loss 1.779001, train error 65.66,  test loss 1.599140, test error 62.06
# Epoch   300, train loss 1.778163, train error 65.69,  test loss 1.595897, test error 61.69
# Epoch   400, train loss 1.777843, train error 66.08,  test loss 1.599669, test error 61.38
# Epoch   500, train loss 1.777201, train error 65.48,  test loss 1.598763, test error 62.69
# Epoch   600, train loss 1.775926, train error 65.67,  test loss 1.600561, test error 62.81
# Epoch   700, train loss 1.775594, train error 65.98,  test loss 1.593923, test error 62.38
# Epoch   800, train loss 1.775714, train error 65.50,  test loss 1.597839, test error 62.06
# Epoch   900, train loss 1.775182, train error 66.03,  test loss 1.587312, test error 62.19
# Training model with   6 hidden variables
# Epoch     0, train loss 2.247337, train error 83.33,  test loss 2.220287, test error 82.00
# Epoch   100, train loss 1.694978, train error 60.97,  test loss 1.463645, test error 56.94
# Epoch   200, train loss 1.659363, train error 59.41,  test loss 1.423255, test error 53.06
# Epoch   300, train loss 1.650712, train error 58.08,  test loss 1.416972, test error 53.31
# Epoch   400, train loss 1.645791, train error 57.58,  test loss 1.418278, test error 51.81
# Epoch   500, train loss 1.640071, train error 57.66,  test loss 1.412423, test error 53.19
# Epoch   600, train loss 1.617778, train error 56.94,  test loss 1.401890, test error 52.44
# Epoch   700, train loss 1.613575, train error 57.02,  test loss 1.398296, test error 52.00
# Epoch   800, train loss 1.611325, train error 56.56,  test loss 1.401823, test error 52.50
# Epoch   900, train loss 1.612269, train error 57.06,  test loss 1.405656, test error 52.50
# Training model with   8 hidden variables
# Epoch     0, train loss 2.200896, train error 81.66,  test loss 2.177215, test error 80.94
# Epoch   100, train loss 1.633747, train error 58.45,  test loss 1.448980, test error 56.62
# Epoch   200, train loss 1.588280, train error 56.50,  test loss 1.410730, test error 53.75
# Epoch   300, train loss 1.570543, train error 55.17,  test loss 1.405244, test error 52.50
# Epoch   400, train loss 1.565964, train error 54.69,  test loss 1.387065, test error 52.62
# Epoch   500, train loss 1.558561, train error 54.98,  test loss 1.390297, test error 51.50
# Epoch   600, train loss 1.551678, train error 55.47,  test loss 1.383189, test error 52.19
# Epoch   700, train loss 1.551207, train error 55.30,  test loss 1.380924, test error 50.81
# Epoch   800, train loss 1.545123, train error 54.88,  test loss 1.382936, test error 51.38
# Epoch   900, train loss 1.544609, train error 54.75,  test loss 1.381918, test error 51.31
# Training model with  10 hidden variables
# Epoch     0, train loss 2.097389, train error 79.61,  test loss 2.028554, test error 78.50
# Epoch   100, train loss 1.523934, train error 51.86,  test loss 1.317994, test error 48.19
# Epoch   200, train loss 1.450298, train error 48.73,  test loss 1.250962, test error 45.19
# Epoch   300, train loss 1.440451, train error 48.16,  test loss 1.254525, test error 45.56
# Epoch   400, train loss 1.436986, train error 48.39,  test loss 1.256986, test error 45.75
# Epoch   500, train loss 1.424660, train error 47.77,  test loss 1.252854, test error 45.81
# Epoch   600, train loss 1.428218, train error 48.34,  test loss 1.261571, test error 46.19
# Epoch   700, train loss 1.426510, train error 47.91,  test loss 1.268363, test error 45.56
# Epoch   800, train loss 1.421292, train error 48.23,  test loss 1.267605, test error 45.44
# Epoch   900, train loss 1.416540, train error 47.36,  test loss 1.256183, test error 45.56
# Training model with  14 hidden variables
# Epoch     0, train loss 2.165591, train error 81.48,  test loss 2.126366, test error 81.25
# Epoch   100, train loss 1.502655, train error 51.19,  test loss 1.362783, test error 51.69
# Epoch   200, train loss 1.446324, train error 49.70,  test loss 1.322123, test error 49.56
# Epoch   300, train loss 1.423027, train error 48.36,  test loss 1.318076, test error 48.69
# Epoch   400, train loss 1.411942, train error 48.05,  test loss 1.327561, test error 49.00
# Epoch   500, train loss 1.405453, train error 47.83,  test loss 1.339336, test error 49.50
# Epoch   600, train loss 1.395715, train error 47.41,  test loss 1.345104, test error 50.62
# Epoch   700, train loss 1.393600, train error 47.78,  test loss 1.351029, test error 50.12
# Epoch   800, train loss 1.391612, train error 47.42,  test loss 1.359967, test error 50.12
# Epoch   900, train loss 1.389768, train error 47.50,  test loss 1.347004, test error 50.31
# Training model with  18 hidden variables
# Epoch     0, train loss 2.149340, train error 78.78,  test loss 2.101752, test error 76.19
# Epoch   100, train loss 1.372319, train error 45.22,  test loss 1.233583, test error 46.00
# Epoch   200, train loss 1.304706, train error 42.91,  test loss 1.237013, test error 45.12
# Epoch   300, train loss 1.275994, train error 42.19,  test loss 1.245807, test error 46.19
# Epoch   400, train loss 1.256251, train error 41.42,  test loss 1.251655, test error 45.38
# Epoch   500, train loss 1.243743, train error 40.77,  test loss 1.270813, test error 44.75
# Epoch   600, train loss 1.237921, train error 41.03,  test loss 1.284213, test error 45.88
# Epoch   700, train loss 1.234053, train error 40.78,  test loss 1.294477, test error 46.62
# Epoch   800, train loss 1.229723, train error 41.36,  test loss 1.309135, test error 46.19
# Epoch   900, train loss 1.222262, train error 40.53,  test loss 1.305352, test error 45.69
# Training model with  22 hidden variables
# Epoch     0, train loss 2.073764, train error 76.19,  test loss 2.014056, test error 75.88
# Epoch   100, train loss 1.291826, train error 41.75,  test loss 1.156091, test error 41.75
# Epoch   200, train loss 1.227348, train error 40.00,  test loss 1.194031, test error 41.94
# Epoch   300, train loss 1.186557, train error 38.70,  test loss 1.214789, test error 42.31
# Epoch   400, train loss 1.190289, train error 39.45,  test loss 1.252738, test error 44.00
# Epoch   500, train loss 1.159456, train error 38.14,  test loss 1.250100, test error 43.75
# Epoch   600, train loss 1.150123, train error 37.11,  test loss 1.242750, test error 43.00
# Epoch   700, train loss 1.158986, train error 38.12,  test loss 1.273369, test error 44.50
# Epoch   800, train loss 1.143301, train error 37.42,  test loss 1.263373, test error 43.19
# Epoch   900, train loss 1.139402, train error 37.59,  test loss 1.288025, test error 43.00
# Training model with  26 hidden variables
# Epoch     0, train loss 2.047994, train error 77.12,  test loss 1.970618, test error 76.25
# Epoch   100, train loss 1.229581, train error 39.56,  test loss 1.195423, test error 43.50
# Epoch   200, train loss 1.145169, train error 37.30,  test loss 1.229614, test error 43.06
# Epoch   300, train loss 1.093443, train error 35.27,  test loss 1.273921, test error 45.31
# Epoch   400, train loss 1.075151, train error 35.09,  test loss 1.306897, test error 45.62
# Epoch   500, train loss 1.053282, train error 34.91,  test loss 1.305357, test error 45.31
# Epoch   600, train loss 1.043053, train error 33.95,  test loss 1.318298, test error 45.75
# Epoch   700, train loss 1.028191, train error 34.05,  test loss 1.317320, test error 45.31
# Epoch   800, train loss 1.023208, train error 33.17,  test loss 1.319970, test error 44.81
# Epoch   900, train loss 1.009999, train error 33.17,  test loss 1.356305, test error 45.56
# Training model with  30 hidden variables
# Epoch     0, train loss 2.048748, train error 77.69,  test loss 1.978197, test error 75.69
# Epoch   100, train loss 1.202816, train error 39.38,  test loss 1.210378, test error 46.12
# Epoch   200, train loss 1.085478, train error 35.45,  test loss 1.301992, test error 47.50
# Epoch   300, train loss 1.034260, train error 33.83,  test loss 1.367186, test error 47.69
# Epoch   400, train loss 1.006085, train error 32.97,  test loss 1.437415, test error 48.88
# Epoch   500, train loss 0.973371, train error 31.75,  test loss 1.461632, test error 47.88
# Epoch   600, train loss 0.963316, train error 31.62,  test loss 1.553907, test error 47.94
# Epoch   700, train loss 0.966470, train error 31.92,  test loss 1.581514, test error 47.94
# Epoch   800, train loss 0.935874, train error 30.58,  test loss 1.618752, test error 48.31
# Epoch   900, train loss 0.944565, train error 30.83,  test loss 1.625852, test error 48.62
# Training model with  35 hidden variables
# Epoch     0, train loss 2.034553, train error 76.11,  test loss 1.973946, test error 75.44
# Epoch   100, train loss 1.077646, train error 34.48,  test loss 1.222920, test error 44.50
# Epoch   200, train loss 0.958899, train error 31.17,  test loss 1.355062, test error 45.50
# Epoch   300, train loss 0.874340, train error 28.00,  test loss 1.464240, test error 46.12
# Epoch   400, train loss 0.826882, train error 26.98,  test loss 1.575621, test error 48.06
# Epoch   500, train loss 0.804070, train error 25.89,  test loss 1.659714, test error 48.50
# Epoch   600, train loss 0.785182, train error 25.94,  test loss 1.690055, test error 47.25
# Epoch   700, train loss 0.774612, train error 25.36,  test loss 1.778874, test error 48.50
# Epoch   800, train loss 0.759655, train error 24.64,  test loss 1.780255, test error 48.50
# Epoch   900, train loss 0.755150, train error 24.08,  test loss 1.851449, test error 49.38
# Training model with  40 hidden variables
# Epoch     0, train loss 2.070041, train error 76.20,  test loss 2.003031, test error 74.62
# Epoch   100, train loss 1.023563, train error 32.02,  test loss 1.220378, test error 43.56
# Epoch   200, train loss 0.848598, train error 27.05,  test loss 1.391758, test error 46.06
# Epoch   300, train loss 0.795095, train error 25.45,  test loss 1.587167, test error 48.06
# Epoch   400, train loss 0.740476, train error 24.09,  test loss 1.692353, test error 49.25
# Epoch   500, train loss 0.699003, train error 22.36,  test loss 1.765310, test error 49.88
# Epoch   600, train loss 0.678894, train error 22.12,  test loss 1.881156, test error 51.00
# Epoch   700, train loss 0.678380, train error 22.22,  test loss 1.941370, test error 50.06
# Epoch   800, train loss 0.638341, train error 20.72,  test loss 2.050333, test error 50.12
# Epoch   900, train loss 0.627404, train error 20.30,  test loss 2.143399, test error 51.06
# Training model with  45 hidden variables
# Epoch     0, train loss 2.046159, train error 76.83,  test loss 1.968953, test error 74.69
# Epoch   100, train loss 0.935957, train error 30.00,  test loss 1.243320, test error 44.81
# Epoch   200, train loss 0.749673, train error 23.92,  test loss 1.564206, test error 49.06
# Epoch   300, train loss 0.651342, train error 21.34,  test loss 1.828690, test error 49.75
# Epoch   400, train loss 0.608027, train error 20.44,  test loss 2.060984, test error 50.25
# Epoch   500, train loss 0.585275, train error 19.75,  test loss 2.258988, test error 49.75
# Epoch   600, train loss 0.546483, train error 18.28,  test loss 2.458140, test error 52.12
# Epoch   700, train loss 0.552618, train error 18.66,  test loss 2.677467, test error 52.81
# Epoch   800, train loss 0.522064, train error 18.45,  test loss 2.782557, test error 51.69
# Epoch   900, train loss 0.499839, train error 17.17,  test loss 2.978297, test error 51.88
# Training model with  50 hidden variables
# Epoch     0, train loss 1.997964, train error 75.03,  test loss 1.892304, test error 73.31
# Epoch   100, train loss 0.811291, train error 25.19,  test loss 1.298077, test error 44.69
# Epoch   200, train loss 0.587911, train error 18.53,  test loss 1.752000, test error 46.94
# Epoch   300, train loss 0.483533, train error 16.19,  test loss 2.316340, test error 49.75
# Epoch   400, train loss 0.405360, train error 13.47,  test loss 2.783799, test error 49.38
# Epoch   500, train loss 0.400922, train error 13.69,  test loss 3.387336, test error 50.56
# Epoch   600, train loss 0.340839, train error 11.75,  test loss 3.804409, test error 51.94
# Epoch   700, train loss 0.351758, train error 12.98,  test loss 4.382567, test error 52.62
# Epoch   800, train loss 0.317473, train error 11.59,  test loss 4.715023, test error 52.81
# Epoch   900, train loss 0.312080, train error 11.06,  test loss 5.173229, test error 51.31
# Training model with  55 hidden variables
# Epoch     0, train loss 2.003737, train error 75.38,  test loss 1.923217, test error 73.94
# Epoch   100, train loss 0.757304, train error 23.73,  test loss 1.379887, test error 45.25
# Epoch   200, train loss 0.484017, train error 16.09,  test loss 1.985086, test error 49.94
# Epoch   300, train loss 0.378043, train error 13.25,  test loss 2.775989, test error 51.25
# Epoch   400, train loss 0.317340, train error 11.11,  test loss 3.541068, test error 51.50
# Epoch   500, train loss 0.258986, train error 9.38,  test loss 4.321734, test error 52.94
# Epoch   600, train loss 0.233573, train error 8.48,  test loss 4.989319, test error 52.38
# Epoch   700, train loss 0.274919, train error 9.42,  test loss 5.654204, test error 52.75
# Epoch   800, train loss 0.273585, train error 8.89,  test loss 6.311554, test error 53.62
# Epoch   900, train loss 0.264320, train error 9.05,  test loss 6.698301, test error 53.94
# Training model with  60 hidden variables
# Epoch     0, train loss 1.983724, train error 74.36,  test loss 1.899017, test error 73.00
# Epoch   100, train loss 0.681724, train error 21.08,  test loss 1.392868, test error 43.31
# Epoch   200, train loss 0.387343, train error 12.16,  test loss 2.298937, test error 50.12
# Epoch   300, train loss 0.266777, train error 9.17,  test loss 3.561522, test error 52.38
# Epoch   400, train loss 0.171698, train error 5.70,  test loss 4.698380, test error 52.94
# Epoch   500, train loss 0.123828, train error 4.42,  test loss 5.803468, test error 52.94
# Epoch   600, train loss 0.009342, train error 0.00,  test loss 6.868435, test error 52.69
# Epoch   700, train loss 0.004859, train error 0.00,  test loss 7.446951, test error 52.56
# Epoch   800, train loss 0.003508, train error 0.00,  test loss 7.843595, test error 52.44
# Epoch   900, train loss 0.002758, train error 0.00,  test loss 8.154234, test error 52.69
# Training model with  70 hidden variables
# Epoch     0, train loss 1.977934, train error 73.52,  test loss 1.874990, test error 72.25
# Epoch   100, train loss 0.545556, train error 16.45,  test loss 1.642838, test error 48.19
# Epoch   200, train loss 0.181358, train error 4.84,  test loss 3.004832, test error 49.06
# Epoch   300, train loss 0.018478, train error 0.00,  test loss 4.562510, test error 49.81
# Epoch   400, train loss 0.007664, train error 0.00,  test loss 5.333067, test error 49.50
# Epoch   500, train loss 0.004783, train error 0.00,  test loss 5.799477, test error 49.50
# Epoch   600, train loss 0.003423, train error 0.00,  test loss 6.136934, test error 49.62
# Epoch   700, train loss 0.002640, train error 0.00,  test loss 6.412290, test error 49.62
# Epoch   800, train loss 0.002122, train error 0.00,  test loss 6.631034, test error 49.69
# Epoch   900, train loss 0.001765, train error 0.00,  test loss 6.821431, test error 49.81
# Training model with  80 hidden variables
# Epoch     0, train loss 1.984493, train error 75.03,  test loss 1.923665, test error 75.12
# Epoch   100, train loss 0.395706, train error 11.48,  test loss 1.691958, test error 46.44
# Epoch   200, train loss 0.035047, train error 0.02,  test loss 3.323470, test error 48.50
# Epoch   300, train loss 0.009604, train error 0.00,  test loss 4.224910, test error 49.00
# Epoch   400, train loss 0.005229, train error 0.00,  test loss 4.690206, test error 49.25
# Epoch   500, train loss 0.003485, train error 0.00,  test loss 5.007159, test error 49.62
# Epoch   600, train loss 0.002573, train error 0.00,  test loss 5.251977, test error 49.81
# Epoch   700, train loss 0.002021, train error 0.00,  test loss 5.441601, test error 49.69
# Epoch   800, train loss 0.001653, train error 0.00,  test loss 5.604845, test error 49.44
# Epoch   900, train loss 0.001392, train error 0.00,  test loss 5.742882, test error 49.44
# Training model with  90 hidden variables
# Epoch     0, train loss 1.944951, train error 71.52,  test loss 1.850103, test error 70.38
# Epoch   100, train loss 0.273010, train error 6.83,  test loss 2.003416, test error 49.50
# Epoch   200, train loss 0.017487, train error 0.00,  test loss 3.447305, test error 50.38
# Epoch   300, train loss 0.006667, train error 0.00,  test loss 4.055838, test error 50.62
# Epoch   400, train loss 0.003936, train error 0.00,  test loss 4.413029, test error 50.44
# Epoch   500, train loss 0.002718, train error 0.00,  test loss 4.659945, test error 50.69
# Epoch   600, train loss 0.002050, train error 0.00,  test loss 4.855749, test error 50.69
# Epoch   700, train loss 0.001631, train error 0.00,  test loss 5.011841, test error 50.81
# Epoch   800, train loss 0.001345, train error 0.00,  test loss 5.143879, test error 50.75
# Epoch   900, train loss 0.001141, train error 0.00,  test loss 5.259940, test error 50.75
# Training model with 100 hidden variables
# Epoch     0, train loss 1.963450, train error 72.94,  test loss 1.866642, test error 72.62
# Epoch   100, train loss 0.172917, train error 3.03,  test loss 2.055264, test error 48.25
# Epoch   200, train loss 0.012096, train error 0.00,  test loss 3.200327, test error 47.38
# Epoch   300, train loss 0.005304, train error 0.00,  test loss 3.643831, test error 47.88
# Epoch   400, train loss 0.003262, train error 0.00,  test loss 3.916281, test error 47.75
# Epoch   500, train loss 0.002296, train error 0.00,  test loss 4.112825, test error 47.81
# Epoch   600, train loss 0.001752, train error 0.00,  test loss 4.264240, test error 47.94
# Epoch   700, train loss 0.001403, train error 0.00,  test loss 4.388403, test error 47.81
# Epoch   800, train loss 0.001165, train error 0.00,  test loss 4.494401, test error 47.75
# Epoch   900, train loss 0.000992, train error 0.00,  test loss 4.585322, test error 47.81
# Training model with 120 hidden variables
# Epoch     0, train loss 1.930523, train error 70.17,  test loss 1.822796, test error 71.50
# Epoch   100, train loss 0.066156, train error 0.14,  test loss 2.090894, test error 45.44
# Epoch   200, train loss 0.008851, train error 0.00,  test loss 2.846444, test error 46.06
# Epoch   300, train loss 0.004218, train error 0.00,  test loss 3.158455, test error 46.38
# Epoch   400, train loss 0.002650, train error 0.00,  test loss 3.359074, test error 46.44
# Epoch   500, train loss 0.001900, train error 0.00,  test loss 3.504689, test error 46.62
# Epoch   600, train loss 0.001466, train error 0.00,  test loss 3.620059, test error 46.69
# Epoch   700, train loss 0.001183, train error 0.00,  test loss 3.715561, test error 46.88
# Epoch   800, train loss 0.000987, train error 0.00,  test loss 3.795866, test error 47.00
# Epoch   900, train loss 0.000843, train error 0.00,  test loss 3.865965, test error 46.94
# Training model with 140 hidden variables
# Epoch     0, train loss 1.934856, train error 71.31,  test loss 1.816581, test error 70.62
# Epoch   100, train loss 0.035581, train error 0.00,  test loss 2.170681, test error 44.94
# Epoch   200, train loss 0.007013, train error 0.00,  test loss 2.738075, test error 45.44
# Epoch   300, train loss 0.003529, train error 0.00,  test loss 3.004184, test error 45.50
# Epoch   400, train loss 0.002289, train error 0.00,  test loss 3.178351, test error 45.75
# Epoch   500, train loss 0.001660, train error 0.00,  test loss 3.305060, test error 45.81
# Epoch   600, train loss 0.001292, train error 0.00,  test loss 3.404949, test error 45.75
# Epoch   700, train loss 0.001048, train error 0.00,  test loss 3.489005, test error 45.69
# Epoch   800, train loss 0.000878, train error 0.00,  test loss 3.559872, test error 45.75
# Epoch   900, train loss 0.000752, train error 0.00,  test loss 3.623840, test error 45.75
# Training model with 160 hidden variables
# Epoch     0, train loss 1.904880, train error 71.23,  test loss 1.792249, test error 68.69
# Epoch   100, train loss 0.024150, train error 0.00,  test loss 2.005539, test error 45.94
# Epoch   200, train loss 0.005824, train error 0.00,  test loss 2.431435, test error 45.75
# Epoch   300, train loss 0.003052, train error 0.00,  test loss 2.635837, test error 45.62
# Epoch   400, train loss 0.002007, train error 0.00,  test loss 2.772746, test error 45.81
# Epoch   500, train loss 0.001471, train error 0.00,  test loss 2.875313, test error 45.75
# Epoch   600, train loss 0.001149, train error 0.00,  test loss 2.954882, test error 45.44
# Epoch   700, train loss 0.000937, train error 0.00,  test loss 3.021574, test error 45.31
# Epoch   800, train loss 0.000787, train error 0.00,  test loss 3.078472, test error 45.38
# Epoch   900, train loss 0.000676, train error 0.00,  test loss 3.128165, test error 45.31
# Training model with 180 hidden variables
# Epoch     0, train loss 1.866930, train error 67.27,  test loss 1.752823, test error 67.50
# Epoch   100, train loss 0.019829, train error 0.00,  test loss 1.960005, test error 44.69
# Epoch   200, train loss 0.005300, train error 0.00,  test loss 2.346967, test error 44.69
# Epoch   300, train loss 0.002831, train error 0.00,  test loss 2.539576, test error 44.88
# Epoch   400, train loss 0.001878, train error 0.00,  test loss 2.668354, test error 45.00
# Epoch   500, train loss 0.001385, train error 0.00,  test loss 2.765808, test error 45.00
# Epoch   600, train loss 0.001084, train error 0.00,  test loss 2.841183, test error 45.00
# Epoch   700, train loss 0.000886, train error 0.00,  test loss 2.904623, test error 45.06
# Epoch   800, train loss 0.000745, train error 0.00,  test loss 2.959802, test error 45.19
# Epoch   900, train loss 0.000641, train error 0.00,  test loss 3.007638, test error 45.19
# Training model with 200 hidden variables
# Epoch     0, train loss 1.865395, train error 67.20,  test loss 1.749549, test error 66.56
# Epoch   100, train loss 0.017813, train error 0.00,  test loss 1.953816, test error 44.38
# Epoch   200, train loss 0.004922, train error 0.00,  test loss 2.286629, test error 44.94
# Epoch   300, train loss 0.002674, train error 0.00,  test loss 2.455747, test error 44.69
# Epoch   400, train loss 0.001786, train error 0.00,  test loss 2.568376, test error 45.06
# Epoch   500, train loss 0.001318, train error 0.00,  test loss 2.653689, test error 44.94
# Epoch   600, train loss 0.001036, train error 0.00,  test loss 2.720840, test error 44.75
# Epoch   700, train loss 0.000848, train error 0.00,  test loss 2.777282, test error 44.75
# Epoch   800, train loss 0.000714, train error 0.00,  test loss 2.825978, test error 44.81
# Epoch   900, train loss 0.000615, train error 0.00,  test loss 2.869032, test error 44.56
# Training model with 250 hidden variables
# Epoch     0, train loss 1.843431, train error 66.11,  test loss 1.738932, test error 66.19
# Epoch   100, train loss 0.013296, train error 0.00,  test loss 1.923689, test error 42.12
# Epoch   200, train loss 0.004174, train error 0.00,  test loss 2.190597, test error 42.44
# Epoch   300, train loss 0.002330, train error 0.00,  test loss 2.337315, test error 42.50
# Epoch   400, train loss 0.001577, train error 0.00,  test loss 2.438480, test error 43.00
# Epoch   500, train loss 0.001175, train error 0.00,  test loss 2.512826, test error 42.94
# Epoch   600, train loss 0.000929, train error 0.00,  test loss 2.574241, test error 43.06
# Epoch   700, train loss 0.000764, train error 0.00,  test loss 2.623704, test error 42.94
# Epoch   800, train loss 0.000646, train error 0.00,  test loss 2.667865, test error 43.06
# Epoch   900, train loss 0.000557, train error 0.00,  test loss 2.705944, test error 42.94
# Training model with 300 hidden variables
# Epoch     0, train loss 1.843200, train error 66.38,  test loss 1.737579, test error 66.38
# Epoch   100, train loss 0.011279, train error 0.00,  test loss 1.822236, test error 42.75
# Epoch   200, train loss 0.003792, train error 0.00,  test loss 2.058940, test error 43.50
# Epoch   300, train loss 0.002147, train error 0.00,  test loss 2.182440, test error 43.56
# Epoch   400, train loss 0.001465, train error 0.00,  test loss 2.269137, test error 43.44
# Epoch   500, train loss 0.001097, train error 0.00,  test loss 2.334651, test error 43.62
# Epoch   600, train loss 0.000870, train error 0.00,  test loss 2.387969, test error 43.56
# Epoch   700, train loss 0.000717, train error 0.00,  test loss 2.433632, test error 43.69
# Epoch   800, train loss 0.000607, train error 0.00,  test loss 2.471272, test error 43.62
# Epoch   900, train loss 0.000525, train error 0.00,  test loss 2.505129, test error 43.62
# Training model with 400 hidden variables
# Epoch     0, train loss 1.802206, train error 63.39,  test loss 1.718705, test error 63.75
# Epoch   100, train loss 0.009147, train error 0.00,  test loss 1.680340, test error 41.94
# Epoch   200, train loss 0.003287, train error 0.00,  test loss 1.856182, test error 41.62
# Epoch   300, train loss 0.001910, train error 0.00,  test loss 1.956325, test error 41.44
# Epoch   400, train loss 0.001318, train error 0.00,  test loss 2.026011, test error 41.62
# Epoch   500, train loss 0.000994, train error 0.00,  test loss 2.079236, test error 41.69
# Epoch   600, train loss 0.000792, train error 0.00,  test loss 2.121726, test error 41.69
# Epoch   700, train loss 0.000655, train error 0.00,  test loss 2.157905, test error 41.56
# Epoch   800, train loss 0.000556, train error 0.00,  test loss 2.189032, test error 41.50
# Epoch   900, train loss 0.000482, train error 0.00,  test loss 2.216430, test error 41.44

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
