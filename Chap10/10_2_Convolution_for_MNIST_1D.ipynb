# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure
# 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you
# will see the words "TODO". Follow the instructions at these places and make
# predictions about what is going to happen or write code to complete the
# functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any
# suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/m5/s7c6nvgs0q321pw3z5mmqc1r0000gn/T/pip-req-build-rd_2p4ps
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/m5/s7c6nvgs0q321pw3z5mmqc1r0000gn/T/pip-req-build-rd_2p4ps
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (2.34.2)
# Requirement already satisfied: numpy in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (2.4.6)
# Requirement already satisfied: matplotlib in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (3.10.9)
# Requirement already satisfied: scipy in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from mnist1d==0.0.2.post16) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/agoth/Desktop/self-study/deep-learning/dl-book/udl-notebooks/.venv/lib/python3.13/site-packages (from requests->mnist1d==0.0.2.post16) (2026.5.20)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(
    args, path="./mnist1d_data.pkl", download=False, regenerate=False
)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data["y"])))
print("Examples in test set: {}".format(len(data["y_test"])))
print("Length of each example: {}".format(data["x"].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data["x"].transpose()
train_data_y = data["y"]
val_data_x = data["x_test"].transpose()
val_data_y = data["y_test"]
# Print out sizes
print(
    "Train data: %d examples (columns), each of which has %d dimensions (rows)"
    % ((train_data_x.shape[1], train_data_x.shape[0]))
)
print(
    "Validation data: %d examples (columns), each of which has %d dimensions (rows)"
    % ((val_data_x.shape[1], val_data_x.shape[0]))
)
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(1, 15, 3, 2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(15, 15, 3, 2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(15, 15, 3, 2, padding="valid"),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10),
)

# %%
# He initialization of weights
def weights_init(layer_in):
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_uniform_(layer_in.weight)
        layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype("float32"))
y_train = torch.tensor(train_data_y.astype("long")).long()
x_val = torch.tensor(val_data_x.transpose().astype("float32"))
y_val = torch.tensor(val_data_y.astype("long")).long()

# load the data into a class that creates the batches
data_loader = DataLoader(
    TensorDataset(x_train, y_train),
    batch_size=100,
    shuffle=True,
    worker_init_fn=np.random.seed(1),
)

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
    # loop over batches
    for i, data in enumerate(data_loader):
        # retrieve inputs and labels for this batch
        x_batch, y_batch = data
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward pass -- calculate model output
        pred = model(x_batch[:, None, :])
        # compute the loss
        loss = loss_function(pred, y_batch)
        # backward pass
        loss.backward()
        # SGD update
        optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train[:, None, :])
    pred_val = model(x_val[:, None, :])
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_val_class = torch.max(pred_val.data, 1)
    errors_train[epoch] = 100 - 100 * (
        predicted_train_class == y_train
    ).float().sum() / len(y_train)
    errors_val[epoch] = 100 - 100 * (predicted_val_class == y_val).float().sum() / len(
        y_val
    )
    losses_train[epoch] = loss_function(pred_train, y_train).item()
    losses_val[epoch] = loss_function(pred_val, y_val).item()
    print(
        f"Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}"
    )

    # tell scheduler to consider updating learning rate
    scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train, "r-", label="train")
ax.plot(errors_val, "b-", label="validation")
ax.set_ylim(0, 100)
ax.set_xlim(0, n_epoch)
ax.set_xlabel("Epoch")
ax.set_ylabel("Error")
ax.set_title("Part I: Validation Result %3.2f" % (errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.962572, train error 79.12,  val loss 1.984656, percent error 80.80
# Epoch     1, train loss 1.500649, train error 59.45,  val loss 1.532545, percent error 63.50
# Epoch     2, train loss 1.403623, train error 58.05,  val loss 1.418566, percent error 58.80
# Epoch     3, train loss 1.336609, train error 54.92,  val loss 1.359808, percent error 55.70
# Epoch     4, train loss 1.228622, train error 51.10,  val loss 1.238151, percent error 51.60
# Epoch     5, train loss 1.142453, train error 46.55,  val loss 1.162234, percent error 49.20
# Epoch     6, train loss 1.086862, train error 44.30,  val loss 1.106631, percent error 46.00
# Epoch     7, train loss 1.010359, train error 40.33,  val loss 1.067087, percent error 44.10
# Epoch     8, train loss 0.984209, train error 40.72,  val loss 1.038001, percent error 42.40
# Epoch     9, train loss 0.832854, train error 33.45,  val loss 0.882162, percent error 37.00
# Epoch    10, train loss 0.727252, train error 29.55,  val loss 0.766053, percent error 30.30
# Epoch    11, train loss 0.669954, train error 26.65,  val loss 0.720919, percent error 30.30
# Epoch    12, train loss 0.640438, train error 25.25,  val loss 0.717610, percent error 28.50
# Epoch    13, train loss 0.601184, train error 22.75,  val loss 0.672897, percent error 25.10
# Epoch    14, train loss 0.592061, train error 21.60,  val loss 0.666407, percent error 23.80
# Epoch    15, train loss 0.486912, train error 16.95,  val loss 0.582069, percent error 20.30
# Epoch    16, train loss 0.394468, train error 13.78,  val loss 0.485020, percent error 17.10
# Epoch    17, train loss 0.415461, train error 14.78,  val loss 0.555385, percent error 19.70
# Epoch    18, train loss 0.352655, train error 12.38,  val loss 0.468242, percent error 15.80
# Epoch    19, train loss 0.329581, train error 11.35,  val loss 0.462841, percent error 16.80
# Epoch    20, train loss 0.252209, train error 8.25,  val loss 0.382520, percent error 13.00
# Epoch    21, train loss 0.240838, train error 7.93,  val loss 0.399764, percent error 13.70
# Epoch    22, train loss 0.226752, train error 7.47,  val loss 0.381261, percent error 12.50
# Epoch    23, train loss 0.259430, train error 8.60,  val loss 0.398982, percent error 13.20
# Epoch    24, train loss 0.199791, train error 6.55,  val loss 0.370197, percent error 11.90
# Epoch    25, train loss 0.200993, train error 6.62,  val loss 0.386718, percent error 13.00
# Epoch    26, train loss 0.203196, train error 7.12,  val loss 0.380892, percent error 13.80
# Epoch    27, train loss 0.165852, train error 5.35,  val loss 0.345866, percent error 11.90
# Epoch    28, train loss 0.186076, train error 6.10,  val loss 0.374180, percent error 11.50
# Epoch    29, train loss 0.172804, train error 5.88,  val loss 0.355823, percent error 11.00
# Epoch    30, train loss 0.144537, train error 4.30,  val loss 0.308464, percent error 10.20
# Epoch    31, train loss 0.135858, train error 4.18,  val loss 0.295296, percent error 9.40
# Epoch    32, train loss 0.126034, train error 3.78,  val loss 0.304837, percent error 10.10
# Epoch    33, train loss 0.129876, train error 4.25,  val loss 0.320381, percent error 10.30
# Epoch    34, train loss 0.129328, train error 4.30,  val loss 0.327563, percent error 10.70
# Epoch    35, train loss 0.112040, train error 3.30,  val loss 0.304960, percent error 9.40
# Epoch    36, train loss 0.141537, train error 4.90,  val loss 0.355459, percent error 11.30
# Epoch    37, train loss 0.141896, train error 4.90,  val loss 0.329455, percent error 10.50
# Epoch    38, train loss 0.131386, train error 4.32,  val loss 0.361461, percent error 11.40
# Epoch    39, train loss 0.155642, train error 5.57,  val loss 0.372120, percent error 10.20
# Epoch    40, train loss 0.090742, train error 2.55,  val loss 0.302384, percent error 9.90
# Epoch    41, train loss 0.089948, train error 2.65,  val loss 0.333005, percent error 11.00
# Epoch    42, train loss 0.079866, train error 2.25,  val loss 0.308251, percent error 9.70
# Epoch    43, train loss 0.079650, train error 2.25,  val loss 0.304520, percent error 9.30
# Epoch    44, train loss 0.076403, train error 2.07,  val loss 0.308955, percent error 9.10
# Epoch    45, train loss 0.079912, train error 2.18,  val loss 0.320877, percent error 9.90
# Epoch    46, train loss 0.070262, train error 1.72,  val loss 0.306562, percent error 8.90
# Epoch    47, train loss 0.069441, train error 1.88,  val loss 0.305298, percent error 9.30
# Epoch    48, train loss 0.069048, train error 1.90,  val loss 0.315051, percent error 10.20
# Epoch    49, train loss 0.073060, train error 1.88,  val loss 0.318121, percent error 8.90
# Epoch    50, train loss 0.068364, train error 1.47,  val loss 0.312601, percent error 8.90
# Epoch    51, train loss 0.062718, train error 1.53,  val loss 0.317146, percent error 9.50
# Epoch    52, train loss 0.062110, train error 1.60,  val loss 0.317241, percent error 9.00
# Epoch    53, train loss 0.058421, train error 1.28,  val loss 0.318278, percent error 8.90
# Epoch    54, train loss 0.064941, train error 1.85,  val loss 0.340935, percent error 9.70
# Epoch    55, train loss 0.061592, train error 1.53,  val loss 0.319471, percent error 8.70
# Epoch    56, train loss 0.057601, train error 1.35,  val loss 0.325410, percent error 8.50
# Epoch    57, train loss 0.059184, train error 1.62,  val loss 0.339872, percent error 9.50
# Epoch    58, train loss 0.059100, train error 1.40,  val loss 0.325011, percent error 9.50
# Epoch    59, train loss 0.056240, train error 1.70,  val loss 0.332404, percent error 8.80
# Epoch    60, train loss 0.050459, train error 1.10,  val loss 0.325000, percent error 9.50
# Epoch    61, train loss 0.048765, train error 1.05,  val loss 0.327773, percent error 9.00
# Epoch    62, train loss 0.049355, train error 1.03,  val loss 0.330817, percent error 8.90
# Epoch    63, train loss 0.047391, train error 0.85,  val loss 0.333417, percent error 9.20
# Epoch    64, train loss 0.046058, train error 0.78,  val loss 0.329751, percent error 9.00
# Epoch    65, train loss 0.045315, train error 0.82,  val loss 0.328878, percent error 8.80
# Epoch    66, train loss 0.045380, train error 0.75,  val loss 0.338346, percent error 9.20
# Epoch    67, train loss 0.044857, train error 0.65,  val loss 0.332080, percent error 8.70
# Epoch    68, train loss 0.044814, train error 0.85,  val loss 0.330881, percent error 8.90
# Epoch    69, train loss 0.045769, train error 0.88,  val loss 0.341197, percent error 9.00
# Epoch    70, train loss 0.043535, train error 0.65,  val loss 0.336015, percent error 9.20
# Epoch    71, train loss 0.042346, train error 0.75,  val loss 0.338297, percent error 8.70
# Epoch    72, train loss 0.042921, train error 0.62,  val loss 0.334121, percent error 8.60
# Epoch    73, train loss 0.045276, train error 0.75,  val loss 0.337926, percent error 8.50
# Epoch    74, train loss 0.042725, train error 0.75,  val loss 0.339079, percent error 9.00
# Epoch    75, train loss 0.041429, train error 0.65,  val loss 0.340974, percent error 8.70
# Epoch    76, train loss 0.042359, train error 0.72,  val loss 0.350915, percent error 9.30
# Epoch    77, train loss 0.040517, train error 0.75,  val loss 0.340122, percent error 8.80
# Epoch    78, train loss 0.039007, train error 0.57,  val loss 0.346871, percent error 9.20
# Epoch    79, train loss 0.039162, train error 0.60,  val loss 0.343361, percent error 9.00
# Epoch    80, train loss 0.038397, train error 0.55,  val loss 0.345839, percent error 9.00
# Epoch    81, train loss 0.037518, train error 0.57,  val loss 0.345968, percent error 9.10
# Epoch    82, train loss 0.037605, train error 0.55,  val loss 0.347199, percent error 9.00
# Epoch    83, train loss 0.037297, train error 0.57,  val loss 0.349444, percent error 9.30
# Epoch    84, train loss 0.036831, train error 0.50,  val loss 0.349277, percent error 9.30
# Epoch    85, train loss 0.036712, train error 0.55,  val loss 0.349843, percent error 9.20
# Epoch    86, train loss 0.036576, train error 0.53,  val loss 0.351682, percent error 9.50
# Epoch    87, train loss 0.036074, train error 0.53,  val loss 0.351156, percent error 9.40
# Epoch    88, train loss 0.035883, train error 0.43,  val loss 0.352172, percent error 9.30
# Epoch    89, train loss 0.035631, train error 0.53,  val loss 0.353461, percent error 9.40
# Epoch    90, train loss 0.037268, train error 0.62,  val loss 0.361224, percent error 9.30
# Epoch    91, train loss 0.035329, train error 0.50,  val loss 0.353362, percent error 9.20
# Epoch    92, train loss 0.035197, train error 0.45,  val loss 0.355212, percent error 9.60
# Epoch    93, train loss 0.035530, train error 0.53,  val loss 0.357842, percent error 9.40
# Epoch    94, train loss 0.035127, train error 0.47,  val loss 0.356262, percent error 9.20
# Epoch    95, train loss 0.034384, train error 0.53,  val loss 0.357772, percent error 9.30
# Epoch    96, train loss 0.034050, train error 0.45,  val loss 0.357747, percent error 9.40
# Epoch    97, train loss 0.034154, train error 0.50,  val loss 0.360299, percent error 9.70
# Epoch    98, train loss 0.033780, train error 0.43,  val loss 0.359566, percent error 9.70
# Epoch    99, train loss 0.033864, train error 0.47,  val loss 0.362269, percent error 9.40
